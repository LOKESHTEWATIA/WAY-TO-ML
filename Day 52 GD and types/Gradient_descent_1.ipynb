# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_regression

# %%
x, y = make_regression(n_samples = 4 , n_features=1 , n_informative=1, n_targets = 1,noise=80, random_state=2)

# %%
plt.scatter(x,y)

# %%
#using OLS
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([93.15173497])

# %%
reg.intercept_
# Out:
# np.float64(-33.59995559847465)

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red')

# %%
# Lets apply Gradient Descent assuming slope is constant m = 16.3
# and let's assume the starting value for intercept b = 10
y_pred = ((16.3*x) + 10)

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red', label='OLS')
plt.plot(x,y_pred,color='green', label='b=0')
plt.legend()
plt.show()

# %%
m = 37
b = 19

slope = -2*np.sum(y - m*x.ravel() - b)
slope
# Out:
# np.float64(529.6160877122502)

# %%
lr = 0.01
b1 = b - lr*slope
b1
# Out:
# np.float64(13.703839122877497)

# %%
y_pred1 = ((m*x) + b1)
y_pred1
# Out:
# array([[ 11.62196652],
#        [ 74.39385903],
#        [ -1.71620123],
#        [-65.33541642]])

# %%
slope_new1 = -2*np.sum(y - m*x.ravel() - b1)
slope_new1
# Out:
# np.float64(487.24680069527017)

# %%
b2 = b1 - lr*slope_new1
b2
# Out:
# np.float64(8.831371115924796)

# %%
y_pred2 = ((m*x) + b2)
y_pred2
# Out:
# array([[  6.74949851],
#        [ 69.52139103],
#        [ -6.58866924],
#        [-70.20788442]])

# %%
slope_new2 = -2*np.sum(y - m*x.ravel() - b2)
slope_new2
# Out:
# np.float64(448.26705663964856)

# %%
y_pred1 = ((m*x) + b1)

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red', label='OLS')
plt.plot(x,y_pred,color='green', label='b=0')
plt.plot(x,y_pred1,color = 'blue', label = b1)
plt.plot(x,y_pred2,color = 'black', label = b2)
plt.legend()
plt.show()

# %%
b = -100
m = 22.35
lr = 0.01

epochs = 300

for i in range(epochs):
  loss_slope = -2 * np.sum(y - m*x.ravel() - b)
  b = b - (lr * loss_slope)

  y_pred = m * x + b

  plt.plot(x,y_pred)

plt.scatter(x,y)
